# %%
x = [1,2,3,4,3]

print(len(x)//2 )

1//2

for x ,y in x:
 print("x=" ,x)

 print("y=" ,y)
# Out:
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 print(len(x)//2 )
#       5 1//2
# ----> 7 for x ,y in x:
#       8  print("x=" ,x)
#      10  print("y=" ,y)
#
# TypeError: cannot unpack non-iterable int object

# %%
x = "you"

sorted(x)
# Out:
# ['o', 'u', 'y']

# %%
x = [(2,4), (6,9), (11,15)]
i = (3,8)

x.append((i))

print (x)
# Out:
# [(2, 4), (6, 9), (11, 15), (3, 8)]
